# %%
import duckdb 
df = duckdb.query("select * from read_parquet('c:/git/wikistats/data/enriched/*enriched.parquet', union_by_name = true)").to_df()
df
# Out:
#       timestamp                   user  \
# 0    1769780867               DPLA bot
# 1    1769780868  SailingthroughHistory
# 2    1769780867         Carol Petrescu
# 3    1769780870          ~2026-62240-9
# 4    1769780869              Melonoone
# ..          ...                    ...
# 140  1769791064     PantheraLeo1359531
# 141  1769791065              CavlakBOT
# 142  1769791065          SecretName101
# 143  1769791064     PantheraLeo1359531
# 144  1769791064     PantheraLeo1359531
#
#                                                  title  \
# 0              Category:Artworks without Wikidata item
# 1               Panshih-class fast combat support ship
# 2                                             Sucevița
# 3                                     The Lion King 1½
# 4          Categorie:Districtul Aki (prefectura Kōchi)
# ..                                                 ...
# 140     Category:PD-USGov missing SDC copyright status
# 141                                       casualisasse
# 142  File:03042023-outdoor-game-v-cle 52729637972 o...
# 143  Category:2025 Hurricane Erin imagery (NOAA Eme...
# 144  Category:Images from NOAA uploaded by Panthera...
#
#                                                comment    bot  minor  \
# 0    [[:File:Number 219 (Serial 219) (Part 1 of 2) ...   True   <NA>
# 1                                       Added template  False  False
# 2                 /* List of Presidents of Sucevița */  False  False
# 3                                                       False  False
# 4    [[:Categorie:Tano, Kōchi]] a fost adăugată în ...  False   <NA>
# ..                                                 ...    ...    ...
# 140  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...  False   <NA>
# 141               yeni sayfa  [[Vikipedi:AWB|AWB]] ile   True  False
# 142              added [[Category:CCM Hockey helmets]]  False   True
# 143  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...  False   <NA>
# 144  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...  False   <NA>
#
#                server_name          wiki  length_new  length_old wikidata_id  \
# 0    commons.wikimedia.org   commonswiki         NaN         NaN   Q27469748
# 1         en.wikipedia.org        enwiki     10900.0     10845.0   Q65062112
# 2         en.wikipedia.org        enwiki      9321.0      9275.0   Q16427563
# 3         en.wikiquote.org   enwikiquote     19882.0     19797.0     Q223217
# 4         ro.wikipedia.org        rowiki         NaN         NaN   Q18991595
# ..                     ...           ...         ...         ...         ...
# 140  commons.wikimedia.org   commonswiki         NaN         NaN        None
# 141      tr.wiktionary.org  trwiktionary        86.0         NaN        None
# 142  commons.wikimedia.org   commonswiki     11261.0     11229.0        None
# 143  commons.wikimedia.org   commonswiki         NaN         NaN        None
# 144  commons.wikimedia.org   commonswiki         NaN         NaN        None
#
#      instance_of subclass_of
# 0    [Q15647814]        <NA>
# 1      [Q559026]   [Q162986]
# 2      [Q659103]        <NA>
# 3      [Q202866]        <NA>
# 4     [Q4167836]        <NA>
# ..           ...         ...
# 140         <NA>        <NA>
# 141         <NA>        <NA>
# 142         <NA>        <NA>
# 143         <NA>        <NA>
# 144         <NA>        <NA>
#
# [145 rows x 13 columns]

# %%
list(df)
# Out:
# ['timestamp',
#  'user',
#  'title',
#  'comment',
#  'bot',
#  'minor',
#  'server_name',
#  'wiki',
#  'length_new',
#  'length_old',
#  'wikidata_id',
#  'instance_of',
#  'subclass_of']

# %%
import sys
from pathlib import Path

# Add src directory to path so we can import wikistats
# Assumes notebook is in notebooks/ folder at project root
src_dir = Path.cwd().parent / "src"
sys.path.insert(0, str(src_dir))

from wikistats.ingestion.stream_ingestion import ingest
from wikistats.enrichment.wikidata_enrichment import enrich

# Run the pipeline
files = ingest( timeout=20)
print(f"\nIngested files: {files}")
enrich(files)
print("Pipeline complete!")
# Out:
# Starting ingestion… writing to C:\git\wikistats\data\raw
# Connected to Wikipedia EventStream…
# Processing event: Category:Information field template with formatting (type: categorize)
# Processing event: Category:Media contributed by the Digital Public Library of America (type: categorize)
# Processing event: Category:Media contributed by the National Archives and Records Administration (type: categorize)
# Processing event: Category:Media contributed by National Archives at College Park - Textual Reference (type: categorize)
# Processing event: Category:Digital Public Library of America files missing required SDC statements (type: categorize)
# Processing event: Category:Digital Public Library of America files missing creator (type: categorize)
# Processing event: Category:PD US (type: categorize)
# Processing event: File:LL-Q36236 (mal)-BhagyaMohan-മരുപഥം.wav (type: edit)
# Processing event: Category:PD-US missing SDC copyright status (type: categorize)
# Processing event: Category:Artworks without Wikidata item (type: categorize)
# Processing event: Thảo luận Thành viên:123.27.156.41 (type: log)
# Processing event: Leopoldo Rubinacci (type: edit)
# Processing event: Nationalist Congress Party (type: edit)
# Processing event: Category:PD US NOAA (type: categorize)
# Processing event: Category:PD-USGov missing SDC copyright status (type: categorize)
# Processing event: Category:Images from NOAA uploaded by PantheraLeo1359531 (type: categorize)
# Processing event: Category:GOES-19 imagery of the late January 2026 North American winter storm (Band 13) (type: categorize)
# Processing event: Category:Category-Class WikiProject Cities pages (type: categorize)
# Processing event: Category:All WikiProject Cities pages (type: categorize)
# Processing event: Category:Files uploaded by PantheraLeo1359531 (type: categorize)
# Processing event: განხილვა:იოჰან ბაპტისტ კრამერი (type: new)
# Processing event: María de Mendoza (type: edit)
# Processing event: Category:Lingua Libre pronunciation-mal (type: categorize)
# Processing event: Category:Files uploaded with OpenRefine by PantheraLeo1359531 (type: categorize)
# Processing event: Category:Taken with Nikon D700 (type: categorize)
# Processing event: File:Mapillary (schermy at) 2019-05-30 09H30M09S900 (821553981787814 at hmzff7hlqylmom42yr0g7q with samsung SM-G930F).jpg (type: edit)
# Processing event: Category:CC-BY-SA-4.0 (type: categorize)
# Processing event: Category:Uploaded with OpenRefine (type: categorize)
# Processing event: Thảo luận Thành viên:14.184.119.240 (type: log)
# Processing event: File:St Luke's Court (formerly St Luke's Church), Franklin Square, Harrogate (NHLE Code 1149446) (July 2023, seen from Harrogate Railway Station).jpg (type: log)
# Processing event: File:20260220851 GOES19-ABI-CONUS-12-5000x3000.jpg (type: log)
# Processing event: خط إس (type: new)
# Processing event: Q104875945 (type: edit)
# Processing event: رده:مقاله‌های ایجادشده توسط ایجادگر (type: categorize)
# Processing event: رده:مقاله‌های ایجاد شده توسط ایجادگر (type: categorize)
# Processing event: File:Toronto protest banner criticising Harper's Israel-Lebanon response.jpg (type: edit)
# Processing event: File:Odette Siko en 1932.jpg (type: edit)
# Processing event: Category:Mam na Gualainn (type: categorize)
# Processing event: Wikidata:WikiProject Heads of state and government/lists/presidents of Bolivia (type: edit)
# Processing event: Category:Kilmallie (type: categorize)
# Processing event: Q136408482 (type: edit)
# Processing event: File:נטיעת עץ תות לכבוד טו בשבט על ידי יהודה שפירא ברחוב התשבי בנשר 13.jpg (type: edit)
# Processing event: Thảo luận Thành viên:14.175.199.195 (type: log)
# Processing event: Лента новостей 26 января 2020 года (type: edit)
# Processing event: File:Mark Rydahl band spelar pa Kulturnatten 2010 (2).jpg (type: edit)
# Processing event: نقاش المستخدم:Enas alfzani (type: new)
# Processing event: contractualisa (type: new)
# Processing event: Iga Świątek (type: edit)
# Processing event: File:Яковлеве-менонітський будинок.jpg (type: edit)
# Processing event: Category:Listed buildings in England with known IDs (type: categorize)
# Processing batch of 50 events…
# Converting 50 events to Arrow format…
# Converted to Arrow table with 50 rows.
# Wrote 50 events → C:\git\wikistats\data\raw\pageviews_20260131_155112_8a7a99d2.parquet
# Processing event: Обговорення:Primus inter pares (type: new)
# Processing event: Category:Listed buildings in England missing SDC depicts (type: categorize)
# Processing event: Category:Listed buildings in England missing SDC location of creation (type: categorize)
# Processing event: Category:CC-Zero (type: categorize)
# Processing event: File:Esquelbecq - Le chateau - Pigeonnier.JPG (type: edit)
# Processing event: Category:Creative Commons CC0 1.0 Universal Public Domain Dedication missing SDC copyright license (type: categorize)
# Processing event: File:20260220851 GOES19-ABI-CONUS-12-5000x3000.jpg (type: edit)
# Processing event: Category:Self-published work (type: categorize)
# Processing event: File:Ughtasar Petroglyphs, Armenia Ուխտասարի ժայռապատկերներ, Հայաստան (15.09.2019) 190.jpg (type: edit)
# Processing event: Category:Self-published work missing SDC copyright license (type: categorize)
# Processing event: File:Jeu de cartes allemand au portrait à deux têtes, avec paysages allemands sur les as - jeu de cartes, estampe - btv1b10516104k (016 of 104).jpg (type: edit)
# Processing event: File:Győr, révfalui Nepomuki Szent János-szobor 2020 02.jpg (type: edit)
# Processing event: Category:St Luke's Church, Harrogate (type: categorize)
# Processing event: Category:Uploaded with pattypan (type: categorize)
# Processing event: Ben Risinger (type: edit)
# Processing event: Category:PD US NOAA (type: categorize)
# Processing event: Category:PD-USGov missing SDC copyright status (type: categorize)
# Processing event: نقاش المستخدم:SrWesly (type: new)
# Processing event: Benutzer:Dieter Zoubek/Artikelentwurf (type: edit)
# Processing event: Category:Images from NOAA uploaded by PantheraLeo1359531 (type: categorize)
# Processing event: Category:GOES-19 imagery of the late January 2026 North American winter storm (Band 12) (type: categorize)
# Processing event: File:Полтавський район Заворскло Пам'ятний знак полеглим воїнам-землякам 02.JPG (type: edit)
# Processing event: Category:Files uploaded by PantheraLeo1359531 (type: categorize)
# Processing event: رده:مقاله‌های ایجادشده توسط ایجادگر (type: categorize)
# Processing event: رده:مقاله‌های ایجاد شده توسط ایجادگر (type: categorize)
# Processing event: Category:Files uploaded with OpenRefine by PantheraLeo1359531 (type: categorize)
# Processing event: Category:Uploaded with OpenRefine (type: categorize)
# Processing event: Q18667729 (type: edit)
# Processing event: File:Number 110 (Serial 127) (Part 2 of 2) - DPLA - 901409b87e6f051289e11077d593a7a4 (page 43).jpg (type: log)
# Processing event: Jahrbücher für musikalische Wissenschaft (type: edit)
# Processing event: Q112475383 (type: edit)
# Processing event: Q104872817 (type: edit)
# Processing event: File:NTSB Most Wanted List 2014- Eliminate Distraction in Transportation (11981940034).jpg (type: log)
# Processing event: File:Pachypodium geayi kz04.jpg (type: edit)
# Processing event: Galaxy Zoo (type: edit)
# Processing event: File:20230212 Kalmthout 49b.jpg (type: edit)
# Processing event: Category:Taken with Nikon D700 (type: categorize)
# Processing event: Kategori:Fransızca sözcükler (type: categorize)
# Processing event: Категорія:Статті проєкту Політика невідомого рівня (type: categorize)
# Processing event: Kategori:Fransızca çekimli eylemler (type: categorize)
# Processing event: Категорія:Статті проєкту Політика низької важливості (type: categorize)
# Processing event: Category:Alfa Romeo 6C Super Sport 1750 (type: categorize)
# Processing event: Beijing Daxing International Airport (type: edit)
# Processing event: Category:Alfa Romeo racing cars (type: categorize)
# Processing event: Категорія:Статті проєкту Політика невідомого рівня низької важливості (type: categorize)
# Processing event: Категорія:Статті проєкту Політика (type: categorize)
# Processing event: File:Military Symbol - Unknown Aligned Unit (Bichrome Quatrefoil Frame)- Special Operations Force - Cyber Domain (ADP 1-02, 2018 August 14).svg (type: edit)
# Processing event: Виллибад (type: new)
# Processing event: Лента новостей 22 января 2020 года (type: edit)
# Processing event: File:NTSB Most Wanted List 2014- Eliminate Distraction in Transportation (11981940034).jpg (type: edit)
# Processing batch of 50 events…
# Converting 50 events to Arrow format…
# Converted to Arrow table with 50 rows.
# Wrote 50 events → C:\git\wikistats\data\raw\pageviews_20260131_155113_2cdec2cd.parquet
# Processing event: Thảo luận Thành viên:116.108.46.19 (type: log)
# Processing event: Kategorie:Vake-Park (type: edit)
# Processing event: گروه تی‌کی‌او (type: edit)
# Processing event: File:Etnografski muzej Beograd Dungodung 48.jpg (type: edit)
# Processing event: File:AGP01.jpg (type: edit)
# Processing event: Category:Hamamelis × intermedia 'Spanish Spider' (type: categorize)
# Processing event: File:Saint-Malo (35) Église Saint-Michel de Rothéneuf - Intérieur - Vitrail - 05.jpg (type: edit)
# Processing event: Kategorie:Ehemaliges Verkehrsunternehmen (Vereinigte Staaten) (type: categorize)
# Processing event: مستخدم:نورا الاثرم (type: new)
# Processing event: Kategorie:Ehemaliger Straßenbahnbetrieb (Vereinigte Staaten) (type: categorize)
# Processing event: Category:United States photographs taken on 2014-01-15 (type: categorize)
# Processing event: Thảo luận Thành viên:116.96.1.249 (type: log)
# Processing event: Category:Flickr review needed (type: categorize)
# Processing event: Hans von der Pahlen (type: edit)
# Processing event: Category:Flickr images missing SDC creator (type: categorize)
# Processing event: Kategorie:Verkehr (Minneapolis) (type: categorize)
# Processing event: Modèle:Palette Effectif actuel du Orlando City SC (type: edit)
# Processing event: Category:PD US NTSB (type: categorize)
# Processing event: Category:Information field template with formatting (type: categorize)
# Processing event: Kategorie:Verkehr (St. Paul) (type: categorize)
# Processing event: Category:U.S. National Transportation Safety Board Flickr files uploaded by OptimusPrimeBot (type: categorize)
# Processing event: Q107675634 (type: edit)
# Processing event: Kategorie:Geschichte von Minnesota (type: categorize)
# Processing event: Category:Media contributed by the Digital Public Library of America (type: categorize)
# Processing event: گروه راهپیمایی باغ اسمرالدو (type: edit)
# Processing event: Q137840631 (type: edit)
# Processing event: Category:United States National Transportation Safety Board images (review needed) (type: categorize)
# Processing event: Category:Media contributed by the National Archives and Records Administration (type: categorize)
# Processing event: Q3107638 (type: edit)
# Processing event: Category:Media contributed by National Archives at College Park - Textual Reference (type: categorize)
# Processing event: Category:Digital Public Library of America files missing required SDC statements (type: categorize)
# Processing event: File:Snow (5299817448).jpg (type: edit)
# Processing event: Category:Digital Public Library of America files missing creator (type: categorize)
# Processing event: Thảo luận Thành viên:117.1.16.0 (type: log)
# Processing event: File:OJ C 202400466 of 2024 - ET Estonian.pdf (type: edit)
# Processing event: Category:PD US (type: categorize)
# Processing event: Лента новостей 19 января 2019 года (type: edit)
# Timeout reached, stopping ingestion.
# Processing batch of 37 events…
# Converting 37 events to Arrow format…
# Converted to Arrow table with 37 rows.
# Wrote 37 events → C:\git\wikistats\data\raw\pageviews_20260131_155114_403b0bb2.parquet
# Ingestion complete.
#
# Ingested files: {WindowsPath('C:/git/wikistats/data/raw/pageviews_20260131_155112_8a7a99d2.parquet'), WindowsPath('C:/git/wikistats/data/raw/pageviews_20260131_155114_403b0bb2.parquet'), WindowsPath('C:/git/wikistats/data/raw/pageviews_20260131_155113_2cdec2cd.parquet')}
# Starting enrichment for 3 files…
#
# Reading C:\git\wikistats\data\raw\pageviews_20260131_155112_8a7a99d2.parquet…
# Enriched file written → C:\git\wikistats\data\raw\pageviews_20260131_155112_8a7a99d2_enriched.parquet
#
# Reading C:\git\wikistats\data\raw\pageviews_20260131_155114_403b0bb2.parquet…
# Enriched file written → C:\git\wikistats\data\raw\pageviews_20260131_155114_403b0bb2_enriched.parquet
#
# Reading C:\git\wikistats\data\raw\pageviews_20260131_155113_2cdec2cd.parquet…
# Enriched file written → C:\git\wikistats\data\raw\pageviews_20260131_155113_2cdec2cd_enriched.parquet
#
# Enrichment complete.
# Pipeline complete!

# %%
# Load and display enriched data
enriched_df = duckdb.query("select * from read_parquet('c:/git/wikistats/data/raw/*_enriched.parquet')").to_df()
print(f"Enriched data shape: {enriched_df.shape}")
enriched_df.head()
# Out:
# Enriched data shape: (84, 13)
#     timestamp                   user  \
# 0  1769780867               DPLA bot
# 1  1769780868  SailingthroughHistory
# 2  1769780867         Carol Petrescu
# 3  1769780870          ~2026-62240-9
# 4  1769780869              Melonoone
#
#                                          title  \
# 0      Category:Artworks without Wikidata item
# 1       Panshih-class fast combat support ship
# 2                                     Sucevița
# 3                             The Lion King 1½
# 4  Categorie:Districtul Aki (prefectura Kōchi)
#
#                                              comment    bot  minor  \
# 0  [[:File:Number 219 (Serial 219) (Part 1 of 2) ...   True   <NA>
# 1                                     Added template  False  False
# 2               /* List of Presidents of Sucevița */  False  False
# 3                                                     False  False
# 4  [[:Categorie:Tano, Kōchi]] a fost adăugată în ...  False   <NA>
#
#              server_name         wiki  length_new  length_old wikidata_id  \
# 0  commons.wikimedia.org  commonswiki         NaN         NaN   Q27469748
# 1       en.wikipedia.org       enwiki     10900.0     10845.0   Q65062112
# 2       en.wikipedia.org       enwiki      9321.0      9275.0   Q16427563
# 3       en.wikiquote.org  enwikiquote     19882.0     19797.0     Q223217
# 4       ro.wikipedia.org       rowiki         NaN         NaN   Q18991595
#
#    instance_of subclass_of
# 0  [Q15647814]        <NA>
# 1    [Q559026]   [Q162986]
# 2    [Q659103]        <NA>
# 3    [Q202866]        <NA>
# 4   [Q4167836]        <NA>
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Create wiki_language_region as Seed

# %%
from wikistats.enrichment.wiki_lookup import WIKI_LANGUAGE_REGION

WIKI_LANGUAGE_REGION
# convert to csv and save in wikistats_db/seeds
import pandas as pd
df_lang =pd.DataFrame.from_dict(WIKI_LANGUAGE_REGION, 
                       orient='index', 
                       columns=['region','language'])

df_lang.to_csv('c:/git/wikistats/wikistats_dbt/seeds/wiki_language_region.csv')

# %% [markdown]
# View latest tables in warehouse duckdb

# %%
import duckdb

# Connect to your dev database
conn = duckdb.connect("C:\\git\\wikistats\\warehouse\\dev.duckdb", read_only=True)

try:
    # Check what's in the database
    print("Tables in main schema:")
    tables = conn.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'main'").fetchall()
    print(tables)
    
    # Query the materialized view
    print("\nSample data from stg_wikistats_enriched:")
    df = conn.execute("SELECT * FROM main.stg_wikistats_enriched").df()
    print(df)
    
    # Summary stats
    print("\nRow count:")
    print(conn.execute("SELECT COUNT(*) as row_count FROM main.stg_wikistats_enriched").fetchall())
    
finally:
    print("\nClosing the connection.")
    conn.close()  # Always close the connection
# Out:
# Tables in main schema:
# [('seed_wiki_language_region',), ('stg_wikistats_enriched',)]
#
# Sample data from stg_wikistats_enriched:
#                                                  title          wiki  \
# 0               Panshih-class fast combat support ship        enwiki
# 1                                             Sucevița        enwiki
# 2          Categorie:Districtul Aki (prefectura Kōchi)        rowiki
# 3                     Thảo luận Thành viên:27.76.21.55        viwiki
# 4                                        Meera Jasmine        enwiki
# ..                                                 ...           ...
# 140     Category:PD-USGov missing SDC copyright status   commonswiki
# 141                                       casualisasse  trwiktionary
# 142  File:03042023-outdoor-game-v-cle 52729637972 o...   commonswiki
# 143  Category:2025 Hurricane Erin imagery (NOAA Eme...   commonswiki
# 144  Category:Images from NOAA uploaded by Panthera...   commonswiki
#
#     wikidata_id instance_of subclass_of                region    language  \
# 0     Q65062112     Q559026     Q162986  Global / Anglosphere     English
# 1     Q16427563     Q659103        None  Global / Anglosphere     English
# 2     Q18991595    Q4167836        None     Romania / Moldova    Romanian
# 3          None        None        None               Vietnam  Vietnamese
# 4      Q3519669          Q5        None  Global / Anglosphere     English
# ..          ...         ...         ...                   ...         ...
# 140        None        None        None                  None        None
# 141        None        None        None                  None        None
# 142        None        None        None                  None        None
# 143        None        None        None                  None        None
# 144        None        None        None                  None        None
#
#                       user                                            comment  \
# 0    SailingthroughHistory                                     Added template
# 1           Carol Petrescu               /* List of Presidents of Sucevița */
# 2                Melonoone  [[:Categorie:Tano, Kōchi]] a fost adăugată în ...
# 3                Ladsgroup  Bot: Mass deleting IP talk pages created by Tu...
# 4                Mirror107                                   /* Early life */
# ..                     ...                                                ...
# 140     PantheraLeo1359531  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...
# 141              CavlakBOT               yeni sayfa  [[Vikipedi:AWB|AWB]] ile
# 142          SecretName101              added [[Category:CCM Hockey helmets]]
# 143     PantheraLeo1359531  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...
# 144     PantheraLeo1359531  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...
#
#        bot  minor            server_name  length_new  length_old  \
# 0    False  False       en.wikipedia.org     10900.0     10845.0
# 1    False  False       en.wikipedia.org      9321.0      9275.0
# 2    False   <NA>       ro.wikipedia.org         NaN         NaN
# 3     True   <NA>       vi.wikipedia.org         NaN         NaN
# 4    False  False       en.wikipedia.org     35296.0     34686.0
# ..     ...    ...                    ...         ...         ...
# 140  False   <NA>  commons.wikimedia.org         NaN         NaN
# 141   True  False      tr.wiktionary.org        86.0         NaN
# 142  False   True  commons.wikimedia.org     11261.0     11229.0
# 143  False   <NA>  commons.wikimedia.org         NaN         NaN
# 144  False   <NA>  commons.wikimedia.org         NaN         NaN
#
#         event_timestamp
# 0   2026-01-30 13:47:48
# 1   2026-01-30 13:47:47
# 2   2026-01-30 13:47:49
# 3   2026-01-30 13:47:50
# 4   2026-01-30 13:47:48
# ..                  ...
# 140 2026-01-30 16:37:44
# 141 2026-01-30 16:37:45
# 142 2026-01-30 16:37:45
# 143 2026-01-30 16:37:44
# 144 2026-01-30 16:37:44
#
# [145 rows x 15 columns]
#
# Row count:
# [(145,)]
#
# Closing the connection.

# %%
df
# Out:
#                                                  title          wiki  \
# 0               Panshih-class fast combat support ship        enwiki
# 1                                             Sucevița        enwiki
# 2          Categorie:Districtul Aki (prefectura Kōchi)        rowiki
# 3                     Thảo luận Thành viên:27.76.21.55        viwiki
# 4                                        Meera Jasmine        enwiki
# ..                                                 ...           ...
# 140     Category:PD-USGov missing SDC copyright status   commonswiki
# 141                                       casualisasse  trwiktionary
# 142  File:03042023-outdoor-game-v-cle 52729637972 o...   commonswiki
# 143  Category:2025 Hurricane Erin imagery (NOAA Eme...   commonswiki
# 144  Category:Images from NOAA uploaded by Panthera...   commonswiki
#
#     wikidata_id instance_of subclass_of                region    language  \
# 0     Q65062112     Q559026     Q162986  Global / Anglosphere     English
# 1     Q16427563     Q659103        None  Global / Anglosphere     English
# 2     Q18991595    Q4167836        None     Romania / Moldova    Romanian
# 3          None        None        None               Vietnam  Vietnamese
# 4      Q3519669          Q5        None  Global / Anglosphere     English
# ..          ...         ...         ...                   ...         ...
# 140        None        None        None                  None        None
# 141        None        None        None                  None        None
# 142        None        None        None                  None        None
# 143        None        None        None                  None        None
# 144        None        None        None                  None        None
#
#                       user                                            comment  \
# 0    SailingthroughHistory                                     Added template
# 1           Carol Petrescu               /* List of Presidents of Sucevița */
# 2                Melonoone  [[:Categorie:Tano, Kōchi]] a fost adăugată în ...
# 3                Ladsgroup  Bot: Mass deleting IP talk pages created by Tu...
# 4                Mirror107                                   /* Early life */
# ..                     ...                                                ...
# 140     PantheraLeo1359531  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...
# 141              CavlakBOT               yeni sayfa  [[Vikipedi:AWB|AWB]] ile
# 142          SecretName101              added [[Category:CCM Hockey helmets]]
# 143     PantheraLeo1359531  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...
# 144     PantheraLeo1359531  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...
#
#        bot  minor            server_name  length_new  length_old  \
# 0    False  False       en.wikipedia.org     10900.0     10845.0
# 1    False  False       en.wikipedia.org      9321.0      9275.0
# 2    False   <NA>       ro.wikipedia.org         NaN         NaN
# 3     True   <NA>       vi.wikipedia.org         NaN         NaN
# 4    False  False       en.wikipedia.org     35296.0     34686.0
# ..     ...    ...                    ...         ...         ...
# 140  False   <NA>  commons.wikimedia.org         NaN         NaN
# 141   True  False      tr.wiktionary.org        86.0         NaN
# 142  False   True  commons.wikimedia.org     11261.0     11229.0
# 143  False   <NA>  commons.wikimedia.org         NaN         NaN
# 144  False   <NA>  commons.wikimedia.org         NaN         NaN
#
#         event_timestamp
# 0   2026-01-30 13:47:48
# 1   2026-01-30 13:47:47
# 2   2026-01-30 13:47:49
# 3   2026-01-30 13:47:50
# 4   2026-01-30 13:47:48
# ..                  ...
# 140 2026-01-30 16:37:44
# 141 2026-01-30 16:37:45
# 142 2026-01-30 16:37:45
# 143 2026-01-30 16:37:44
# 144 2026-01-30 16:37:44
#
# [145 rows x 15 columns]
