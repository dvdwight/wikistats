# %%
import duckdb 
df = duckdb.query("select * from read_parquet('c:/git/wikistats/data/enriched/*enriched.parquet', union_by_name = true)").to_df()
df
# Out:
#       timestamp                   user  \
# 0    1769780867               DPLA bot
# 1    1769780868  SailingthroughHistory
# 2    1769780867         Carol Petrescu
# 3    1769780870          ~2026-62240-9
# 4    1769780869              Melonoone
# ..          ...                    ...
# 140  1769791064     PantheraLeo1359531
# 141  1769791065              CavlakBOT
# 142  1769791065          SecretName101
# 143  1769791064     PantheraLeo1359531
# 144  1769791064     PantheraLeo1359531
#
#                                                  title  \
# 0              Category:Artworks without Wikidata item
# 1               Panshih-class fast combat support ship
# 2                                             Sucevița
# 3                                     The Lion King 1½
# 4          Categorie:Districtul Aki (prefectura Kōchi)
# ..                                                 ...
# 140     Category:PD-USGov missing SDC copyright status
# 141                                       casualisasse
# 142  File:03042023-outdoor-game-v-cle 52729637972 o...
# 143  Category:2025 Hurricane Erin imagery (NOAA Eme...
# 144  Category:Images from NOAA uploaded by Panthera...
#
#                                                comment    bot  minor  \
# 0    [[:File:Number 219 (Serial 219) (Part 1 of 2) ...   True   <NA>
# 1                                       Added template  False  False
# 2                 /* List of Presidents of Sucevița */  False  False
# 3                                                       False  False
# 4    [[:Categorie:Tano, Kōchi]] a fost adăugată în ...  False   <NA>
# ..                                                 ...    ...    ...
# 140  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...  False   <NA>
# 141               yeni sayfa  [[Vikipedi:AWB|AWB]] ile   True  False
# 142              added [[Category:CCM Hockey helmets]]  False   True
# 143  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...  False   <NA>
# 144  [[:File:2025 Hurricane Erin-20250823b RGB-raw-...  False   <NA>
#
#                server_name          wiki  length_new  length_old wikidata_id  \
# 0    commons.wikimedia.org   commonswiki         NaN         NaN   Q27469748
# 1         en.wikipedia.org        enwiki     10900.0     10845.0   Q65062112
# 2         en.wikipedia.org        enwiki      9321.0      9275.0   Q16427563
# 3         en.wikiquote.org   enwikiquote     19882.0     19797.0     Q223217
# 4         ro.wikipedia.org        rowiki         NaN         NaN   Q18991595
# ..                     ...           ...         ...         ...         ...
# 140  commons.wikimedia.org   commonswiki         NaN         NaN        None
# 141      tr.wiktionary.org  trwiktionary        86.0         NaN        None
# 142  commons.wikimedia.org   commonswiki     11261.0     11229.0        None
# 143  commons.wikimedia.org   commonswiki         NaN         NaN        None
# 144  commons.wikimedia.org   commonswiki         NaN         NaN        None
#
#      instance_of subclass_of
# 0    [Q15647814]        <NA>
# 1      [Q559026]   [Q162986]
# 2      [Q659103]        <NA>
# 3      [Q202866]        <NA>
# 4     [Q4167836]        <NA>
# ..           ...         ...
# 140         <NA>        <NA>
# 141         <NA>        <NA>
# 142         <NA>        <NA>
# 143         <NA>        <NA>
# 144         <NA>        <NA>
#
# [145 rows x 13 columns]

# %%
list(df)
# Out:
# ['timestamp',
#  'user',
#  'title',
#  'comment',
#  'bot',
#  'minor',
#  'server_name',
#  'wiki',
#  'length_new',
#  'length_old',
#  'wikidata_id',
#  'instance_of',
#  'subclass_of']

# %%
import sys
from pathlib import Path

# Add src directory to path so we can import wikistats
# Assumes notebook is in notebooks/ folder at project root
src_dir = Path.cwd().parent / "src"
sys.path.insert(0, str(src_dir))

from wikistats.ingestion.stream_ingestion import ingest
from wikistats.enrichment.wikidata_enrichment import enrich

# Run the pipeline
files = ingest()
print(f"\nIngested files: {files}")
enrich(files)
print("Pipeline complete!")
# Out:
# Starting ingestion… writing to C:\git\wikistats\data\raw
# Connected to Wikipedia EventStream…
# Processing event: User talk:Zayayz (type: edit)
# Processing event: Category:伯尔尼州山峰 (type: categorize)
# Processing event: Q15747255 (type: edit)
# Processing event: File:Novo aeroporto de Passo Fundo-RS 06.jpg (type: edit)
# Processing event: Carabus gratus (type: edit)
# Processing event: Category:Taken with Olympus C-8080WZ (type: categorize)
# Processing event: Thảo luận Thành viên:115.76.221.204 (type: log)
# Processing event: Q23718501 (type: edit)
# Processing event: Q106049407 (type: edit)
# Processing event: wymuszanie (type: log)
# Processing event: File:Münster, LVM-Versicherung -- 2014 -- 3298.jpg (type: edit)
# Processing event: Q9095333 (type: edit)
# Processing event: Translations:Education/Newsletter/January 2026/Headlines/26/ja (type: new)
# Processing event: User talk:BhagyaMani (type: edit)
# Processing event: File:Arturo Frondizi con Juan XXIII.jpg (type: edit)
# Processing event: Category:Old Church Slavonic links with redundant wikilinks (type: categorize)
# Processing event: ऑगस्ट (type: edit)
# Processing event: Category:Old Church Slavonic links with redundant alt parameters (type: categorize)
# Processing event: File:Valeriana celtica (Echt-Speik) IMG 2618.jpg (type: edit)
# Processing event: File:001-logo-blau-ssch-004c70.png (type: edit)
# Processing event: Q123822953 (type: edit)
# Processing event: Wikipedysta:Cezary Klimaszewski (type: edit)
# Processing event: Taxation in Canada (type: edit)
# Processing event: Q63913984 (type: edit)
# Processing event: Category:CS1 maint: url-status (type: categorize)
# Processing event: Category:Accepted species names (type: categorize)
# Processing event: Category:Accepted species name (type: categorize)
# Processing event: Q1005219 (type: edit)
# Processing event: File:Quim Presidente.jpg (type: edit)
# Processing event: Category:Rhymes:Proto-Germanic/un.θrɑz (type: categorize)
# Processing event: Category:Rhymes:Proto-Germanic/un.θrɑz/2 syllables (type: categorize)
# Processing event: Just Give Me a Reason (type: edit)
# Processing event: August Friedrich Viehweger (type: edit)
# Processing event: Thảo luận Thành viên:14.160.253.42 (type: log)
# Processing event: Category:Papal winter mozzettas (type: categorize)
# Processing event: Category:Taken with Canon EOS 300D (type: categorize)
# Processing event: Category:Winter mozzettas (type: categorize)
# Processing event: Q66625208 (type: edit)
# Processing event: Category:CS1 errors: invisible characters (type: categorize)
# Processing event: File:2025 Hurricane Erin-20250823b RGB-raw-172128 0823251444295 006 RGB2.jpg (type: log)
# Processing event: Category:Media without a source as of 29 January 2026 (type: categorize)
# Processing event: Category:Media without a source as of 23 January 2026 (type: categorize)
# Processing event: Education/Newsletter/January 2026/Headlines/ja (type: edit)
# Processing event: Diego Cuéllar (type: edit)
# Processing event: Q106049342 (type: edit)
# Processing event: File:Valeriana celtica (Echt-Speik) IMG 2623.jpg (type: edit)
# Processing event: File:Evening Standard January 14, 1909 - DPLA - 50985df6a1035b3a8ab1af33c57874a3 (page 12).jpg (type: edit)
# Processing event: File:2025 Hurricane Erin-20250823b RGB-raw-172128 0823251444295 006 RGB2.jpg (type: edit)
# Processing event: File:Dop20rgbi 32 426 5872 2 ni 2014-03-12.tif (type: edit)
# Processing event: Q63913985 (type: edit)
# Processing batch of 50 events…
# Converting 50 events to Arrow format…
# Converted to Arrow table with 50 rows.
# Wrote 50 events → C:\git\wikistats\data\raw\pageviews_20260130_163746_4b551307.parquet
# Processing event: File:Cuthie receives MSM (9035309).jpg (type: edit)
# Processing event: File:Boeckhorst Phoebus.jpg (type: edit)
# Processing event: Thảo luận Thành viên:14.180.71.174 (type: log)
# Processing event: Q1009086 (type: edit)
# Processing event: Category:Maud Margaret Key Stawell (type: edit)
# Processing event: Category:PD US NOAA (type: categorize)
# Processing event: Category:PD-USGov missing SDC copyright status (type: categorize)
# Processing event: casualisasse (type: new)
# Processing event: File:03042023-outdoor-game-v-cle 52729637972 o (52903559408).jpg (type: edit)
# Processing event: Category:2025 Hurricane Erin imagery (NOAA Emergency Response Imagery) (RAW JPEG) (type: categorize)
# Processing event: Category:Images from NOAA uploaded by PantheraLeo1359531 (type: categorize)
# Timeout reached, stopping ingestion.
# Processing batch of 11 events…
# Converting 11 events to Arrow format…
# Converted to Arrow table with 11 rows.
# Wrote 11 events → C:\git\wikistats\data\raw\pageviews_20260130_163747_4e343575.parquet
# Ingestion complete.
#
# Ingested files: {WindowsPath('C:/git/wikistats/data/raw/pageviews_20260130_163747_4e343575.parquet'), WindowsPath('C:/git/wikistats/data/raw/pageviews_20260130_163746_4b551307.parquet')}
# Starting enrichment for 2 files…
#
# Reading C:\git\wikistats\data\raw\pageviews_20260130_163747_4e343575.parquet…
# Enriched file written → C:\git\wikistats\data\raw\pageviews_20260130_163747_4e343575_enriched.parquet
#
# Reading C:\git\wikistats\data\raw\pageviews_20260130_163746_4b551307.parquet…
# Enriched file written → C:\git\wikistats\data\raw\pageviews_20260130_163746_4b551307_enriched.parquet
#
# Enrichment complete.
# Pipeline complete!

# %%
# Load and display enriched data
enriched_df = duckdb.query("select * from read_parquet('c:/git/wikistats/data/raw/*_enriched.parquet')").to_df()
print(f"Enriched data shape: {enriched_df.shape}")
enriched_df.head()
# Out:
# Enriched data shape: (84, 13)
#     timestamp                   user  \
# 0  1769780867               DPLA bot
# 1  1769780868  SailingthroughHistory
# 2  1769780867         Carol Petrescu
# 3  1769780870          ~2026-62240-9
# 4  1769780869              Melonoone
#
#                                          title  \
# 0      Category:Artworks without Wikidata item
# 1       Panshih-class fast combat support ship
# 2                                     Sucevița
# 3                             The Lion King 1½
# 4  Categorie:Districtul Aki (prefectura Kōchi)
#
#                                              comment    bot  minor  \
# 0  [[:File:Number 219 (Serial 219) (Part 1 of 2) ...   True   <NA>
# 1                                     Added template  False  False
# 2               /* List of Presidents of Sucevița */  False  False
# 3                                                     False  False
# 4  [[:Categorie:Tano, Kōchi]] a fost adăugată în ...  False   <NA>
#
#              server_name         wiki  length_new  length_old wikidata_id  \
# 0  commons.wikimedia.org  commonswiki         NaN         NaN   Q27469748
# 1       en.wikipedia.org       enwiki     10900.0     10845.0   Q65062112
# 2       en.wikipedia.org       enwiki      9321.0      9275.0   Q16427563
# 3       en.wikiquote.org  enwikiquote     19882.0     19797.0     Q223217
# 4       ro.wikipedia.org       rowiki         NaN         NaN   Q18991595
#
#    instance_of subclass_of
# 0  [Q15647814]        <NA>
# 1    [Q559026]   [Q162986]
# 2    [Q659103]        <NA>
# 3    [Q202866]        <NA>
# 4   [Q4167836]        <NA>
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from wikistats.enrichment.wiki_lookup import WIKI_LANGUAGE_REGION

WIKI_LANGUAGE_REGION
# convert to csv and save in wikistats_db/seeds
import pandas as pd
df_lang =pd.DataFrame.from_dict(WIKI_LANGUAGE_REGION, 
                       orient='index', 
                       columns=['region','language'])

df_lang.to_csv('c:/git/wikistats/wikistats_dbt/seeds/wiki_language_region.csv')

# %%
import duckdb

# Connect to your dev database
conn = duckdb.connect("C:\\git\\wikistats\\warehouse\\dev.duckdb", read_only=True)

try:
    # Check what's in the database
    print("Tables in main schema:")
    tables = conn.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'main'").fetchall()
    print(tables)
    
    # Query the materialized view
    print("\nSample data from stg_wikistats_enriched:")
    df = conn.execute("SELECT * FROM main.stg_wikistats_enriched LIMIT 5").df()
    print(df)
    
    # Summary stats
    print("\nRow count:")
    print(conn.execute("SELECT COUNT(*) as row_count FROM main.stg_wikistats_enriched").fetchall())
    
finally:
    print("\nClosing the connection.")
    conn.close()  # Always close the connection
# Out:
# Tables in main schema:
# [('stg_wikistats_enriched',)]
#
# Sample data from stg_wikistats_enriched:
# ---------------------------------------------------------------------------
# ConversionException                       Traceback (most recent call last)
# Cell In[1], line 14
#      12 # Query the materialized view
#      13 print("\nSample data from stg_wikistats_enriched:")
# ---> 14 df = conn.execute("SELECT * FROM main.stg_wikistats_enriched LIMIT 5").df()
#      15 print(df)
#      17 # Summary stats
#
# ConversionException: Conversion Error: Unimplemented type for cast (BIGINT -> TIMESTAMP) when casting from source column timestamp
